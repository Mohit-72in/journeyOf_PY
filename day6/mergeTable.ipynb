# %%
import pandas as pd
import numpy as np

# %%
deliveries = pd.read_csv('deliveries.csv')

# %%
deliveries.shape
# Out:
# (150460, 21)

# %%
matches = pd.read_csv('../day5/IPL Matches 2008-2020.csv')

# %%
matches.shape
# Out:
# (816, 18)

# %%
deliveries.merge(matches,left_on='match_id',right_on = 'id')
# Out:
# Empty DataFrame
# Columns: [match_id, inning, batting_team, bowling_team, over, ball, batsman, non_striker, bowler, is_super_over, wide_runs, bye_runs, legbye_runs, noball_runs, penalty_runs, batsman_runs, extra_runs, total_runs, player_dismissed, dismissal_kind, fielder, id, city, date, player_of_match, venue, neutral_venue, team1, team2, toss_winner, toss_decision, winner, result, result_margin, eliminator, method, umpire1, umpire2, season]
# Index: []
#
# [0 rows x 39 columns]
